# %% [markdown]
# **Problem 1:** Create a NumPy array of 20 random integers between 1 and 100. Calculate the mean, median, and standard deviation of the array.

# %%
import numpy as np

random_array = np.random.randint(1, 101, 20)

mean_value = np.mean(random_array)
median_value = np.median(random_array)
std_deviation = np.std(random_array)

print("Random Array:", random_array)
print("Mean:", mean_value)
print("Median:", median_value)
print("Standard Deviation:", std_deviation)
# Out:
# Random Array: [69 16 53 87 53 91 53  6 60 47 88 29 47 60 18 34 33 91 72 41]
# Mean: 52.4
# Median: 53.0
# Standard Deviation: 24.83223711227001

# %% [markdown]
# **Problem 2:** Create a Pandas DataFrame with three columns - 'Name', 'Age', and 'City' - and at least five rows of data. Perform a basic data exploration by displaying the first 3 rows, the last 2 rows, and a summary of statistics for the 'Age' column.

# %%
import pandas as pd

data = {'Name': ['Ali', 'Babak', 'Changiz', 'Davood', 'Effat'],
        'Age': [25, 30, 22, 28, 26],
        'City': ['Nahavand', 'Semnan', 'Lahijan', 'shiraz', 'Mashhad']}

df = pd.DataFrame(data)

print("First 3 rows:")
print(df.head(3))

print("\nLast 2 rows:")
print(df.tail(2))

print("\nSummary statistics for the 'Age' column:")
print(df['Age'].describe())
# Out:
# First 3 rows:
#       Name  Age      City
# 0      Ali   25  Nahavand
# 1    Babak   30    Semnan
# 2  Changiz   22   Lahijan
#
# Last 2 rows:
#      Name  Age     City
# 3  Davood   28   shiraz
# 4   Effat   26  Mashhad
#
# Summary statistics for the 'Age' column:
# count     5.00000
# mean     26.20000
# std       3.03315
# min      22.00000
# 25%      25.00000
# 50%      26.00000
# 75%      28.00000
# max      30.00000
# Name: Age, dtype: float64

# %% [markdown]
# **Problem 3:** Create a bar chart using Matplotlib to visualize the following data: Monthly sales for a store (January to May). Use appropriate labels and titles for the chart.

# %%
import matplotlib.pyplot as plt

months = ['فروردین', 'اردیبهشت', 'خرداد', 'تیر', 'مرداد']
sales = [45000, 52000, 60000, 48000, 55000]

plt.bar(months, sales, color='skyblue')

plt.xlabel('ماه')
plt.ylabel('فروش (ريال)')
plt.title('فروش ماهانه (فروردین تا مرداد)')

plt.show()

# %% [markdown]
# **Problem 4:** Create two NumPy arrays, 'arr1' and 'arr2', both of size 5x5 with random integer values. Perform element-wise addition, subtraction, multiplication, and division between the two arrays.

# %%
import numpy as np

arr1 = np.random.randint(1, 11, size=(5, 5))
arr2 = np.random.randint(1, 11, size=(5, 5))

addition_result = arr1 + arr2

subtraction_result = arr1 - arr2

multiplication_result = arr1 * arr2

division_result = np.divide(arr1, arr2, out=np.zeros_like(arr1, dtype=np.float64), where=arr2 != 0)

print("Array 1:")
print(arr1)
print("\nArray 2:")
print(arr2)
print("\nElement-wise Addition:")
print(addition_result)
print("\nElement-wise Subtraction:")
print(subtraction_result)
print("\nElement-wise Multiplication:")
print(multiplication_result)
print("\nElement-wise Division:")
print(division_result)
# Out:
# Array 1:
# [[10  1  9  7  5]
#  [ 7  2  5  2  5]
#  [ 9  8  5  6  1]
#  [ 8  3  9  8  5]
#  [ 6  8  5  2 10]]
#
# Array 2:
# [[ 4  5  8  1  3]
#  [ 4 10  2  5  3]
#  [ 1  3  3  8  7]
#  [10  1  2  5  2]
#  [10 10  5  1  5]]
#
# Element-wise Addition:
# [[14  6 17  8  8]
#  [11 12  7  7  8]
#  [10 11  8 14  8]
#  [18  4 11 13  7]
#  [16 18 10  3 15]]
#
# Element-wise Subtraction:
# [[ 6 -4  1  6  2]
#  [ 3 -8  3 -3  2]
#  [ 8  5  2 -2 -6]
#  [-2  2  7  3  3]
#  [-4 -2  0  1  5]]
#
# Element-wise Multiplication:
# [[40  5 72  7 15]
#  [28 20 10 10 15]
#  [ 9 24 15 48  7]
#  [80  3 18 40 10]
#  [60 80 25  2 50]]
#
# Element-wise Division:
# [[2.5        0.2        1.125      7.         1.66666667]
#  [1.75       0.2        2.5        0.4        1.66666667]
#  [9.         2.66666667 1.66666667 0.75       0.14285714]
#  [0.8        3.         4.5        1.6        2.5       ]
#  [0.6        0.8        1.         2.         2.        ]]

# %% [markdown]
# **Problem 5:** Given a Pandas DataFrame with information about employees, filter and display only the employees who are older than 30 years.

# %%
import pandas as pd

data = {'Name': ['Ali', 'Babak', 'Changiz', 'Davood', 'Effat'],
        'Age': [32, 28, 35, 26, 42]}

employee_data = pd.DataFrame(data)

older_than_30 = employee_data[employee_data['Age'] > 30]

print(older_than_30)
# Out:
#       Name  Age
# 0      Ali   32
# 2  Changiz   35
# 4    Effat   42

# %% [markdown]
# **Problem 6:** Create a scatter plot using Matplotlib to visualize a dataset of 100 random (x, y) coordinates. Label the axes appropriately and give the plot a title.

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y, marker='o', color='red', s=25)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot of Random (x, y) Coordinates')

plt.show()

# %% [markdown]
# **Problem 7:** Create two NumPy matrices, 'matrix1' (2x3) and 'matrix2' (3x4), with random values. Perform matrix multiplication between the two matrices.

# %%
import numpy as np

matrix1 = np.random.rand(2, 3)
matrix2 = np.random.rand(3, 4)

result_matrix = np.dot(matrix1, matrix2)

print("Matrix 1:")
print(matrix1)
print("\nMatrix 2:")
print(matrix2)
print("\nResult of Matrix Multiplication:")
print(result_matrix)
# Out:
# Matrix 1:
# [[0.31179588 0.69634349 0.37775184]
#  [0.17960368 0.02467873 0.06724963]]
#
# Matrix 2:
# [[0.67939277 0.45369684 0.53657921 0.89667129]
#  [0.99033895 0.21689698 0.6630782  0.26332238]
#  [0.020651   0.75837865 0.32001715 0.38346389]]
#
# Result of Matrix Multiplication:
# [[0.9092489  0.57897454 0.74992045 0.60779543]
#  [0.14785052 0.13783905 0.13425656 0.19333173]]

# %% [markdown]
# **Problem 8:** Given a Pandas DataFrame containing sales data, calculate and display the total sales for each product category.

# %%
import pandas as pd

data = {'Product': ['A', 'B', 'C', 'A', 'B', 'C'],
        'Category': ['X', 'Y', 'Y', 'Y', 'X', 'X'],
        'Sales': [100, 150, 120, 90, 130, 110]}

sales_data = pd.DataFrame(data)

category_sales = sales_data.groupby('Category')['Sales'].sum().reset_index()

print(category_sales)
# Out:
#   Category  Sales
# 0        X    340
# 1        Y    360

# %% [markdown]
# **Problem 9:** Create a line chart using Matplotlib to visualize the population growth of a city over 10 years. Label the axes and provide a title.

# %%
import matplotlib.pyplot as plt

years = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
population = [50000, 52000, 54000, 56000, 59000, 61000, 63000, 65000, 67000, 69000]

plt.plot(years, population, marker='o', linestyle='-', color='b')

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('City Population Growth Over 10 Years')

plt.grid(True)
plt.show()

# %% [markdown]
# **Problem 10:** Given a Pandas DataFrame containing information about students, add a new column 'Grade' based on the following criteria:
# * If 'Score' >= 90, Grade is 'A'
# * If 'Score' >= 80, Grade is 'B'
# * If 'Score' >= 70, Grade is 'C'
# * If 'Score' < 70, Grade is 'D'

# %%
import pandas as pd

data = {'StudentName': ['Ali', 'Babak', 'Changiz', 'Davood', 'Effat'],
        'Score': [95, 82, 68, 75, 60]}

student_data = pd.DataFrame(data)

def calculate_grade(score):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    else:
        return 'D'

student_data['Grade'] = student_data['Score'].apply(calculate_grade)

print(student_data)
# Out:
#   StudentName  Score Grade
# 0         Ali     95     A
# 1       Babak     82     B
# 2     Changiz     68     D
# 3      Davood     75     C
# 4       Effat     60     D

# %% [markdown]
# **Problem 11:** You are given a dataset containing monthly sales data for three products (A, B, and C) over a two-year period. Your task is to perform various data analysis tasks using NumPy, Pandas, and Matplotlib.
#
#
# *   Dataset:
#
# ```
# import pandas as pd
#
# data = {
#     'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
#     'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
#     'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
#     'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
# }
#
# sales_df = pd.DataFrame(data)
# ```
# *  Tasks:
# 1. Calculate and display the total sales for each product over the two-year period.
#
# 2. Calculate and display the average monthly sales for each product.
#
# 3. Find the month with the highest sales for each product, and display the product and the sales value for that month.
#
# 4. Calculate and display the percentage change in sales for each product from January to December in the second year (2022).
#
# 5. Create a line chart using Matplotlib to visualize the monthly sales data for each product over the two-year period. Label the axes and provide a title for the chart.
#
# 6. Calculate the correlation between Product A and Product B sales. Is there a strong correlation between these two products? Display the correlation coefficient.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
    'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
    'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
    'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
}

sales_df = pd.DataFrame(data)

total_sales = sales_df.sum()
print("Total Sales for Each Product:\n",total_sales)

average_monthly_sales = sales_df.mean()
print("\nAverage Monthly Sales for Each Product:\n",average_monthly_sales)

max_sales_month_A = sales_df['Month'][sales_df['Product A Sales'].idxmax()]
max_sales_A = sales_df['Product A Sales'].max()
max_sales_month_B = sales_df['Month'][sales_df['Product B Sales'].idxmax()]
max_sales_B = sales_df['Product B Sales'].max()
max_sales_month_C = sales_df['Month'][sales_df['Product C Sales'].idxmax()]
max_sales_C = sales_df['Product C Sales'].max()
print(f"\nMonth with Highest Sales for Product A: {max_sales_month_A} (Sales: {max_sales_A})")
print(f"Month with Highest Sales for Product B: {max_sales_month_B} (Sales: {max_sales_B})")
print(f"Month with Highest Sales for Product C: {max_sales_month_C} (Sales: {max_sales_C})")

sales_jan_2022 = sales_df.loc[12:23].sum()
sales_dec_2022 = sales_df.loc[0:11].sum()
percentage_change = ((sales_jan_2022 - sales_dec_2022) / sales_dec_2022) * 100
print(f"\nPercentage Change in Sales from January to December 2022:")
print(percentage_change)

plt.figure(figsize=(10, 6))
plt.plot(sales_df['Month'], sales_df['Product A Sales'], label='Product A')
plt.plot(sales_df['Month'], sales_df['Product B Sales'], label='Product B')
plt.plot(sales_df['Month'], sales_df['Product C Sales'], label='Product C')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales Data Over Two Years')
plt.legend()
plt.grid(True)
plt.show()

correlation = sales_df['Product A Sales'].corr(sales_df['Product B Sales'])
print(f"\nCorrelation between Product A and Product B Sales: {correlation}")
# Out:
# <ipython-input-10-9c7f8be103a6>:13: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   total_sales = sales_df.sum()
# <ipython-input-10-9c7f8be103a6>:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   average_monthly_sales = sales_df.mean()
# <ipython-input-10-9c7f8be103a6>:29: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales_jan_2022 = sales_df.loc[12:23].sum()
# <ipython-input-10-9c7f8be103a6>:30: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales_dec_2022 = sales_df.loc[0:11].sum()
# Total Sales for Each Product:
#  Product A Sales    31600
# Product B Sales    23800
# Product C Sales    11510
# dtype: int64
#
# Average Monthly Sales for Each Product:
#  Product A Sales    1316.666667
# Product B Sales     991.666667
# Product C Sales     479.583333
# dtype: float64
#
# Month with Highest Sales for Product A: 2022-12-31 00:00:00 (Sales: 1900)
# Month with Highest Sales for Product B: 2022-12-31 00:00:00 (Sales: 1700)
# Month with Highest Sales for Product C: 2022-12-31 00:00:00 (Sales: 720)
#
# Percentage Change in Sales from January to December 2022:
# Product A Sales     70.085470
# Product B Sales    111.111111
# Product C Sales     74.701671
# dtype: float64
# Correlation between Product A and Product B Sales: 0.954652710589704
